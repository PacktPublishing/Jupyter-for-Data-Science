# %%
#read in the CSV file as available as described above
volcanoes = read.csv("volcanoes.csv")
head(volcanoes)
# Out:
#   Number   Volcano.Name      Country   Region          Latitude Longitude Elev
# 1 1402-08= Acatenango        Guatemala Guatemala       14.501   -90.876   3976
# 2 0803-17= Adatara           Japan     Honshu-Japan    37.620   140.280   1718
# 3 0604-02= Agung             Indonesia Lesser Sunda Is -8.342   115.508   3142
# 4 1000-123 Akademia Nauk     Russia    Kamchatka       53.980   159.450   1180
# 5 0805-07= Akan              Japan     Hokkaido-Japan  43.380   144.020   1499
# 6 0803-23= Akita-Komaga-take Japan     Honshu-Japan    39.750   140.800   1637
#   Type          Status     Last.Known.Eruption
# 1 Stratovolcano Historical D1
# 2 Stratovolcano Historical D1
# 3 Stratovolcano Historical D1
# 4 Stratovolcano Historical D1
# 5 Caldera       Historical D1
# 6 Stratovolcano Historical D1

# %%
install.packages("mapdata",repos = "http://cran.us.r-project.org")
library(maps)
map("world")
points(volcanoes$Longitude, volcanoes$Latitude, pch=16, col="red", cex=1)
# Out:
# package 'mapdata' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\prasadr\AppData\Local\Temp\RtmpI3h94p\downloaded_packages
# Warning message:
# "package 'maps' was built under R version 3.4.2"
# plot without title

# %%
library(ggplot2)
qplot(Longitude, Latitude, data=volcanoes, color=Type, size=Elev, alpha=0.5)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.4.2"Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %%
library(ggplot2) 
qplot(Sepal.Length, Petal.Length, data=iris, color=Species, size=Petal.Length)
# Out:
# plot without title

# %%
library(ggplot2) 
dsmall <- diamonds[sample(nrow(diamonds), 100), ]

(d <- ggplot(dsmall, aes(carat, price)) + geom_point(aes(shape = cut))) +
scale_shape(solid = FALSE)
# Out:
# plot without title

# %%
library(ggplot2) 
ggplot(data=mpg) + 
  geom_point(mapping = aes(x=displ, y=hwy, color=class, size=class))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title
