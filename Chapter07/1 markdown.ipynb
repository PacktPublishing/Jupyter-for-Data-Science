# %% [markdown]
# #You can use markdown that has
# <i>italic</i> and <b>bold</b> text

# %% [markdown]
# <ul>
#     <li>list item 1</li>
#     <li>list item 2</li>
# </ul>

# %% [markdown]
# # Heading 1
# # Heading 2
# ## Heading 2.1
# ## Heading 2.2

# %% [markdown]
# <table>
#     <tr>
#         <th>column 1</th>
#         <th>column 2</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>2</td>
#     </tr>
# </table>

# %% [markdown]
# ```python
# print "Hello World"
# ```
